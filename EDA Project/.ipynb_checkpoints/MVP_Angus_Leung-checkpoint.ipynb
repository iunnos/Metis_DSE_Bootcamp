# %% [markdown]
# ## MVP
# ### Question:
# How effective is the Earth Day marketing campaigns in New York? An effective campaign would expect that people use increased transit (as they would want to use their car less) in the days around Earth Day. Is this trend observable over multiple years?

# %% [markdown]
# ![2021-Bar%20Chart.png](attachment:2021-Bar%20Chart.png)

# %% [markdown]
# ![2022%20Bar%20Chart.png](attachment:2022%20Bar%20Chart.png)

# %% [markdown]
# The initial thought was to compare entries in a bar chart. However this was not as insightful (for the most part) as originally intended. Moving to a line chart offered more valuable comparisons.
#
# The bar charts did highlight an interesting point for data after April 23, 2022. The daily entries suddenly drop off. More on this later.

# %% [markdown]
# ![2021%20Line%20Chart.png](attachment:2021%20Line%20Chart.png)

# %% [markdown]
# Once plotted to a line chart the information is a lot more insightful. We see that leading up to Earth Day the number of Daily Entries does increase. Further analysis of other months will provide more insight regarding the data.

# %% [markdown]
# Coming back to the Data after April 23, 2022. Masking the Data for Daily Entries after April 23, 2022 we do see that the entries have a very apparent drop in Entries.
# ![masked_data_SC.png](attachment:masked_data_SC.png)
#
# We'll need to find some contextual information outside of the data as to why this might have happened. My initial hypothesis is that certain entry points have been shut off as part of New York's Earth day events.

# %% [markdown]
# ## Conclusions
# We do see that there's an increase of Daily Entries as we lead up to Earth Day. While slight, further analysis of trends for the months prior and the months after Earth Day would be insightful. The initial analysis of data leads me to believe that it would be more insightful to look at the data over months within the same year rather than only around April over multiple years.
